# %%
import numpy as np
from math import factorial
import math

def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# ### 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800]. Найдите ее среднее значение и дисперсию.

# %% [markdown]
# $$M(X) = \frac{a + b}{2}$$
# $$D(X) = \frac{(b - a)^2}{12}$$

# %%
a = 200
b = 800
print(f"Среднее значение = {(a + b) * 0.5}")
print(f"Дисперсия = {(b - a) ** 2 / 12}")
# Out:
# Среднее значение = 500.0
# Дисперсия = 30000.0

# %% [markdown]
# ### 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12}$$
# $$(b - a)^2 = 12 \cdot D(X)$$
# $$(b - a) = \sqrt{12 \cdot D(X)}$$
# $$b = a + \sqrt{12 \cdot D(X)}$$

# %%
a = 0.5
D = 0.2
print(f"Правая граница = {math.sqrt(12 * D) + a: .3f}")
print(f"Среднее значение = {math.sqrt(12 * D)/2 + a: .3f}")
# Out:
# Правая граница =  2.049
# Среднее значение =  1.275

# %% [markdown]
# ### Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#  ### f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)**2) / 32).
#  ### Найдите:
#  ### а). M(X)
#  ### б). D(X)
#  ### в). std(X) (среднее квадратичное отклонение)

# %%
print(f"Среднее значение = {-2}")
print(f"Дисперсия = {4**2}")
print(f"СКО = корень из дисперсии = {4}")
# Out:
# Среднее значение = -2
# Дисперсия = 16
# СКО = корень из дисперсии = 4

# %% [markdown]
# ### Рост взрослого населения города X имеет нормальное распределение.
# ### Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# ### Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %%
print(f"а). больше 182 см - все, кроме 1 сигма в 1 сторону= {(100-68)/2: .3f}%")
print(f"б). больше 190 см - все, кроме 2 сигма в 1 сторону= {(100-95.4)/2: .3f}%")
print(f"в). от 166 см до 190 см - 2 сигма в одну сторону и 1 в другую = {(100-95.4)/2+(100-68)/2: .3f}%")
print(f"г). от 166 см до 182 см - 1 сигма= {68}%")
print(f"д). от 158 см до 190 см - 2 сигма = {95.4}%")
print(f"е). не выше 150 см или не ниже 190 см - все, кроме 3 сигма в 1 сторону и все, кроме 2 сигма в другую = {(100 - 99.72)/2 + (100 - 95.4)/2: .3f}%")
print(f"ё). не выше 150 см или не ниже 198 см - все, кроме 3 сигма = {(100 - 99.72): .3f}%")
print(f"ж). ниже 166 см. - все, кроме 1 сигма в 1 сторону = {(100-68)/2: .3f}%")
# Out:
# а). больше 182 см - все, кроме 1 сигма в 1 сторону=  16.000%
# б). больше 190 см - все, кроме 2 сигма в 1 сторону=  2.300%
# в). от 166 см до 190 см - 2 сигма в одну сторону и 1 в другую =  18.300%
# г). от 166 см до 182 см - 1 сигма= 68%
# д). от 158 см до 190 см - 2 сигма = 95.4%
# е). не выше 150 см или не ниже 190 см - все, кроме 3 сигма в 1 сторону и все, кроме 2 сигма в другую =  2.440%
# ё). не выше 150 см или не ниже 198 см - все, кроме 3 сигма =  0.280%
# ж). ниже 166 см. - все, кроме 1 сигма в 1 сторону =  16.000%

# %% [markdown]
# По-нормальному нужно было, конечно, вычитать различные значения функции распределения

# %% [markdown]
# ### На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
print(f"СКО = корень из дисперсии = {5}")
print(f"Отклонение = {(190-178)/5} сигм")
# Out:
# СКО = корень из дисперсии = 5
# Отклонение = 2.4 сигм
